# %% [markdown]
# # Main?
# Alireza: I envisioned that this notebook can be the main training pipeline that calls on various function to generate clean features for the given list of item_id. These dataframes will be merged/joined on item_id and that final dataframe can be used for training and ensembling.
#
# *Note: if this format is acceptable by you, it is preferrable to always pull the latest version of this notebook and then make a pull request (PR) for changing it as it is one of the main files where collaboration happens hence a high chance of unwanted merge conflicts!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import generate_periods_features
# %matplotlib inline

# %%
train_periods_file = 'data/periods_train_featurized.csv'
## 1) when the featurization needs to be refreshed:
train_periods = pd.read_csv('data/periods_train.csv')
# train_periods = generate_periods_features(train_periods)
# train_periods.set_index('item_id').to_csv(train_periods_file)

## 2) when there is a featurized csv is already available on your disk
# train_periods = pd.read_csv(train_periods_file)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-b4b7ec739868> in <module>()
#       2 ## 1) when the featurization needs to be refreshed:
#       3 train_periods = pd.read_csv('data/periods_train.csv')
# ----> 4 train_periods = generate_periods_features(train_periods)
#       5 train_periods.set_index('item_id').to_csv(train_periods_file)
#       6
#
# ~/Documents/gdso-avito/utils.py in generate_periods_features(df)
#      58     df['activation_date'][null_idx] = df['date_from'][null_idx]
#      59     for col in ['activation_date', 'date_from', 'date_to']:
# ---> 60         df[col] = df[col].apply(pd.to_datetime, yearfirst=True)
#      61     assert len(df) == len(df.drop_duplicates('item_id'))
#      62     assert (df['date_to'] > df['date_from']).all()
#
# AssertionError:

# %%
len(train_periods) == len(train_periods.drop_duplicates('item_id'))
# Out:
# False

# %%
train_periods[train_periods['item_id'].duplicated()]
# Out:
#                item_id activation_date  date_from    date_to
# 9581      7fb2f7c83c6f      2017-02-13 2017-03-15 2017-03-15
# 14114     2cc9137abee8      2017-02-21 2017-03-15 2017-03-23
# 20922     abf7a10c3a0c      2017-02-15 2017-03-15 2017-03-17
# 21387     416a2e2cba8b      2017-02-19 2017-03-15 2017-03-21
# 23473     00b26bf899b0      2017-02-25 2017-03-15 2017-03-26
# 25369     0fa8b4a068e9      2017-02-16 2017-03-15 2017-03-18
# 28120     4641c59a4365      2017-02-19 2017-03-15 2017-03-21
# 28503     b56ed1d31fe3      2017-02-16 2017-03-15 2017-03-18
# 29141     8cd30f3fae22      2017-02-22 2017-03-15 2017-03-24
# 31329     6bf6a8d12bcf      2017-03-20 2017-03-20 2017-03-28
# 32022     8475c63479cc      2017-03-24 2017-03-24 2017-03-28
# 32735     7b83dd3bf9f4      2017-02-15 2017-03-15 2017-03-16
# 33034     c9477ffb7b70      2017-02-15 2017-03-15 2017-03-16
# 34955     dd470b895e86      2017-02-14 2017-03-15 2017-03-16
# 37241     7df9418bbdf1      2017-02-26 2017-03-15 2017-03-27
# 37719     ed80ef4be317      2017-02-24 2017-03-15 2017-03-26
# 38267     a6e0db188bc8      2017-02-18 2017-03-15 2017-03-20
# 39229     a0cb75262af8      2017-03-23 2017-03-23 2017-03-28
# 39240     9f3309963d16      2017-02-18 2017-03-15 2017-03-20
# 39895     018233c60be1      2017-03-28 2017-03-28 2017-03-28
# 40766     2ccdbd10d3f3      2017-03-19 2017-03-19 2017-03-28
# 42229     9eac8e5ab142      2017-03-19 2017-03-19 2017-03-28
# 43764     f8b5dd2d23e4      2017-03-22 2017-03-22 2017-03-28
